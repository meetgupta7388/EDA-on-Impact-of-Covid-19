# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mental_health = pd.read_csv('/content/Mental Health in Pregnancy During Covid-  19 - Mental Health in Pregnancy During Covid-  19.csv.csv')

# %%
mental_health.head()
# Out:
#    OSF_ID  Maternal_Age    Household_Income    Maternal_Education  \
# 0       1          38.3           $200,000+        Masters degree
# 1       2          34.6           $200,000+  Undergraduate degree
# 2       3          34.3  $100,000 -$124,999  Undergraduate degree
# 3       4          28.8  $100,000 -$124,999        Masters degree
# 4       5          36.5     $40,000-$69,999  Undergraduate degree
#
#    Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                   9.0            13.0
# 1                                   4.0            17.0
# 2                                   NaN             NaN
# 3                                   9.0            20.0
# 4                                  14.0            20.0
#
#    Gestational_Age_At_Birth Delivery_Date(converted to month and year)  \
# 0                     39.71                                    Dec2020
# 1                       NaN                                        NaN
# 2                       NaN                                        NaN
# 3                     38.57                                    Dec2020
# 4                     39.86                                    Oct2020
#
#    Birth_Length  Birth_Weight                  Delivery_Mode NICU_Stay  \
# 0         49.20        3431.0                      Vaginally        No
# 1           NaN           NaN                            NaN       NaN
# 2           NaN           NaN                            NaN       NaN
# 3         41.00        2534.0                      Vaginally        No
# 4         53.34        3714.0  Caesarean-section (c-section)        No
#
#   Language  Threaten_Life  Threaten_Baby_Danger  Threaten_Baby_Harm
# 0  English            2.0                   3.0                27.0
# 1  English            2.0                  33.0                92.0
# 2   French            NaN                   NaN                 NaN
# 3   French           53.0                  67.0                54.0
# 4  English           23.0                  32.0                71.0

# %%
mental_health.shape
# Out:
# (10772, 16)

# %%
mental_health.columns
# Out:
# Index(['OSF_ID', 'Maternal_Age', 'Household_Income', 'Maternal_Education',
#        'Edinburgh_Postnatal_Depression_Scale', 'PROMIS_Anxiety',
#        'Gestational_Age_At_Birth',
#        'Delivery_Date(converted to month and year)', 'Birth_Length',
#        'Birth_Weight', 'Delivery_Mode', 'NICU_Stay', 'Language',
#        'Threaten_Life', 'Threaten_Baby_Danger', 'Threaten_Baby_Harm'],
#       dtype='object')

# %%
mental_health.drop(columns=['OSF_ID','Language'], inplace = True)

# %%
mental_health.head()
# Out:
#    Maternal_Age    Household_Income    Maternal_Education  \
# 0          38.3           $200,000+        Masters degree
# 1          34.6           $200,000+  Undergraduate degree
# 2          34.3  $100,000 -$124,999  Undergraduate degree
# 3          28.8  $100,000 -$124,999        Masters degree
# 4          36.5     $40,000-$69,999  Undergraduate degree
#
#    Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                   9.0            13.0
# 1                                   4.0            17.0
# 2                                   NaN             NaN
# 3                                   9.0            20.0
# 4                                  14.0            20.0
#
#    Gestational_Age_At_Birth Delivery_Date(converted to month and year)  \
# 0                     39.71                                    Dec2020
# 1                       NaN                                        NaN
# 2                       NaN                                        NaN
# 3                     38.57                                    Dec2020
# 4                     39.86                                    Oct2020
#
#    Birth_Length  Birth_Weight                  Delivery_Mode NICU_Stay  \
# 0         49.20        3431.0                      Vaginally        No
# 1           NaN           NaN                            NaN       NaN
# 2           NaN           NaN                            NaN       NaN
# 3         41.00        2534.0                      Vaginally        No
# 4         53.34        3714.0  Caesarean-section (c-section)        No
#
#    Threaten_Life  Threaten_Baby_Danger  Threaten_Baby_Harm
# 0            2.0                   3.0                27.0
# 1            2.0                  33.0                92.0
# 2            NaN                   NaN                 NaN
# 3           53.0                  67.0                54.0
# 4           23.0                  32.0                71.0

# %%
mental_health.shape
# Out:
# (10772, 14)

# %%
# Identifying rows to drop
rows_to_drop = mental_health[(mental_health['PROMIS_Anxiety'].isnull()) & (mental_health['Delivery_Date(converted to month and year)'].isnull())
& (mental_health['Threaten_Life'].isnull()) & (mental_health['Threaten_Baby_Harm'].isnull()) & (mental_health['Threaten_Baby_Danger'].isnull())].index

# %%
rows_to_drop
# Out:
# Index([    2,    12,    26,    77,   151,   153,   164,   174,   202,   255,
#        ...
#        10635, 10638, 10645, 10657, 10692, 10709, 10738, 10760, 10762, 10768],
#       dtype='int64', length=480)

# %%
mental_health.drop(rows_to_drop, inplace=True)

# %%
mental_health.head()
# Out:
#    Maternal_Age     Household_Income    Maternal_Education  \
# 0          38.3            $200,000+        Masters degree
# 1          34.6            $200,000+  Undergraduate degree
# 3          28.8   $100,000 -$124,999        Masters degree
# 4          36.5      $40,000-$69,999  Undergraduate degree
# 5          38.3  $150,000 - $174,999  Undergraduate degree
#
#    Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                   9.0            13.0
# 1                                   4.0            17.0
# 3                                   9.0            20.0
# 4                                  14.0            20.0
# 5                                   3.0             8.0
#
#    Gestational_Age_At_Birth Delivery_Date(converted to month and year)  \
# 0                     39.71                                    Dec2020
# 1                       NaN                                        NaN
# 3                     38.57                                    Dec2020
# 4                     39.86                                    Oct2020
# 5                     38.57                                    Jun2020
#
#    Birth_Length  Birth_Weight                  Delivery_Mode NICU_Stay  \
# 0         49.20        3431.0                      Vaginally        No
# 1           NaN           NaN                            NaN       NaN
# 3         41.00        2534.0                      Vaginally        No
# 4         53.34        3714.0  Caesarean-section (c-section)        No
# 5           NaN           NaN                            NaN       NaN
#
#    Threaten_Life  Threaten_Baby_Danger  Threaten_Baby_Harm
# 0            2.0                   3.0                27.0
# 1            2.0                  33.0                92.0
# 3           53.0                  67.0                54.0
# 4           23.0                  32.0                71.0
# 5           29.0                  36.0                33.0

# %%
mental_health.shape
# Out:
# (10292, 14)

# %%
# Checking for duplicates
mental_health.duplicated().sum()
# Out:
# 0

# %%
# Checking for null values percentage in dataset
mental_health.isnull().sum()/mental_health.shape[0]*100
# Out:
# Maternal_Age                                   0.864749
# Household_Income                               2.176448
# Maternal_Education                             1.486592
# Edinburgh_Postnatal_Depression_Scale           6.743101
# PROMIS_Anxiety                                 7.054023
# Gestational_Age_At_Birth                      34.570540
# Delivery_Date(converted to month and year)    34.580257
# Birth_Length                                  46.754761
# Birth_Weight                                  40.944423
# Delivery_Mode                                 46.200933
# NICU_Stay                                     46.230082
# Threaten_Life                                  4.041974
# Threaten_Baby_Danger                           4.119705
# Threaten_Baby_Harm                             4.003109
# dtype: float64

# %%
mental_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10292 entries, 0 to 10771
# Data columns (total 14 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Maternal_Age                                10203 non-null  float64
#  1   Household_Income                            10068 non-null  object
#  2   Maternal_Education                          10139 non-null  object
#  3   Edinburgh_Postnatal_Depression_Scale        9598 non-null   float64
#  4   PROMIS_Anxiety                              9566 non-null   float64
#  5   Gestational_Age_At_Birth                    6734 non-null   float64
#  6   Delivery_Date(converted to month and year)  6733 non-null   object
#  7   Birth_Length                                5480 non-null   float64
#  8   Birth_Weight                                6078 non-null   float64
#  9   Delivery_Mode                               5537 non-null   object
#  10  NICU_Stay                                   5534 non-null   object
#  11  Threaten_Life                               9876 non-null   float64
#  12  Threaten_Baby_Danger                        9868 non-null   float64
#  13  Threaten_Baby_Harm                          9880 non-null   float64
# dtypes: float64(9), object(5)
# memory usage: 1.4+ MB

# %%
# Plotting numerical data
numerical_df = mental_health.select_dtypes(include = ['number'])

# %%
numerical_df.head()
# Out:
#    Maternal_Age  Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0          38.3                                   9.0            13.0
# 1          34.6                                   4.0            17.0
# 3          28.8                                   9.0            20.0
# 4          36.5                                  14.0            20.0
# 5          38.3                                   3.0             8.0
#
#    Gestational_Age_At_Birth  Birth_Length  Birth_Weight  Threaten_Life  \
# 0                     39.71         49.20        3431.0            2.0
# 1                       NaN           NaN           NaN            2.0
# 3                     38.57         41.00        2534.0           53.0
# 4                     39.86         53.34        3714.0           23.0
# 5                     38.57           NaN           NaN           29.0
#
#    Threaten_Baby_Danger  Threaten_Baby_Harm
# 0                   3.0                27.0
# 1                  33.0                92.0
# 3                  67.0                54.0
# 4                  32.0                71.0
# 5                  36.0                33.0

# %%
import math

# %%
# Determine the number of columns and rows needed
num_cols = 3
num_plots = numerical_df.shape[1]
num_rows = math.ceil(num_plots / num_cols)

# Create subplots
fig, axs = plt.subplots(num_rows, num_cols, figsize=(4 * num_cols, 4 * num_rows))
axs = axs.flatten()

# Plot each column
for i, col in enumerate(numerical_df.columns):
    sns.kdeplot(data=numerical_df[col], ax=axs[i])
    axs[i].set_title(f'Distribution of {col}')



plt.tight_layout()
plt.show()

# %%
#  Checking for categorical data
categorical_df = mental_health.select_dtypes(include = ['object'])
categorical_df.head()
# Out:
#       Household_Income    Maternal_Education  \
# 0            $200,000+        Masters degree
# 1            $200,000+  Undergraduate degree
# 3   $100,000 -$124,999        Masters degree
# 4      $40,000-$69,999  Undergraduate degree
# 5  $150,000 - $174,999  Undergraduate degree
#
#   Delivery_Date(converted to month and year)                  Delivery_Mode  \
# 0                                    Dec2020                      Vaginally
# 1                                        NaN                            NaN
# 3                                    Dec2020                      Vaginally
# 4                                    Oct2020  Caesarean-section (c-section)
# 5                                    Jun2020                            NaN
#
#   NICU_Stay
# 0        No
# 1       NaN
# 3        No
# 4        No
# 5       NaN

# %%
print(categorical_df['Household_Income'].value_counts())
print('\n')
print(categorical_df['Maternal_Education'].value_counts())
print('\n')
print(categorical_df['Delivery_Mode'].value_counts())
print('\n')
print(categorical_df['NICU_Stay'].value_counts())
# Out:
# Household_Income
# $70,000-$99,999        2006
# $100,000 -$124,999     1886
# $40,000-$69,999        1348
# $125,000- $149,999     1315
# $150,000 - $174,999    1115
# $200,000+               977
# $175,000- $199,999      641
# $20,000- $39,999        561
# Less than $20, 000      219
# Name: count, dtype: int64
#
#
# Maternal_Education
# Undergraduate degree             3979
# College/trade school             2588
# Masters degree                   1849
# High school diploma               835
# Doctoral Degree                   767
# Less than high school diploma     121
# Name: count, dtype: int64
#
#
# Delivery_Mode
# Vaginally                        3904
# Caesarean-section (c-section)    1633
# Name: count, dtype: int64
#
#
# NICU_Stay
# No     4986
# Yes     548
# Name: count, dtype: int64

# %%
fig, axs = plt.subplots(3, 2, figsize=(15, 5 * num_rows))
axs = axs.flatten()

for i, col in enumerate(categorical_df.columns):
    value_counts = categorical_df[col].value_counts()
    cmap = plt.colormaps['viridis']
    colors = [cmap(i / len(value_counts)) for i in range(len(value_counts))]
    axs[i].bar(value_counts.index, value_counts, color=colors)
    axs[i].set_title(f'Distribution of {col}')
    axs[i].set_xlabel(col)
    axs[i].set_ylabel('Count')
    axs[i].tick_params(axis='x', rotation=45)  # Rotate x-axis labels for better readability

# Hide any unused subplots
for j in range(i + 1, len(axs)):
    fig.delaxes(axs[j])

plt.tight_layout()
plt.show()

# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.subplots as sp

# Number of columns per row
cols_per_row = 2
num_plots = categorical_df.shape[1]
num_rows = (num_plots + cols_per_row - 1) // cols_per_row  # Calculate the number of rows needed

# Create subplot figure
fig = sp.make_subplots(rows=num_rows, cols=cols_per_row, subplot_titles=categorical_df.columns)

for i, col in enumerate(categorical_df.columns):
    row = i // cols_per_row + 1
    col_num = i % cols_per_row + 1
    value_counts = categorical_df[col].value_counts()

    # Use different colors for each label
    colors = px.colors.qualitative.Plotly[:len(value_counts)]

    fig.add_trace(
        go.Bar(
            x=value_counts.index,
            y=value_counts,
            marker=dict(color=colors),
            name=f'Distribution of {col}'
        ),
        row=row,
        col=col_num
    )

    fig.update_xaxes(title_text=col, row=row, col=col_num)
    fig.update_yaxes(title_text='Count', row=row, col=col_num)

# Update layout
fig.update_layout(
    height=400 * num_rows,
    title_text='Distribution of Categorical Columns',
    showlegend=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="108a3778-7e08-4006-83d0-b84a25e1000e" class="plotly-graph-div" style="height:1200px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("108a3778-7e08-4006-83d0-b84a25e1000e")) {                    Plotly.newPlot(                        "108a3778-7e08-4006-83d0-b84a25e1000e",                        [{"marker":{"color":["#636EFA","#EF553B","#00CC96","#AB63FA","#FFA15A","#19D3F3","#FF6692","#B6E880","#FF97FF"]},"name":"Distribution of Household_Income","x":["$70,000-$99,999","$100,000 -$124,999","$40,000-$69,999","$125,000- $149,999","$150,000 - $174,999","$200,000+","$175,000- $199,999","$20,000- $39,999","Less than $20, 000"],"y":[2006,1886,1348,1315,1115,977,641,561,219],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":["#636EFA","#EF553B","#00CC96","#AB63FA","#FFA15A","#19D3F3"]},"name":"Distribution of Maternal_Education","x":["Undergraduate degree","College\u002ftrade school","Masters degree","High school diploma","Doctoral Degree","Less than high school diploma"],"y":[3979,2588,1849,835,767,121],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":["#636EFA","#EF553B","#00CC96","#AB63FA","#FFA15A","#19D3F3","#FF6692","#B6E880","#FF97FF","#FECB52"]},"name":"Distribution of Delivery_Date(converted to month and year)","x":["Aug2020","Sep2020","Jul2020","Oct2020","Jun2020","Nov2020","Jan2021","Dec2020","Mar2021","Apr2021","Feb2021","May2021","Jun2021","May2020","Jul2021","Aug2021","Sep2021","Oct2021","Nov2021","Apr2020","Sep2022","Jun2022","Jul2022","Dec2021","Jan2022","Mar2022","Aug2022","Feb2022","May2022"],"y":[684,638,630,619,510,473,413,404,385,342,315,292,281,214,208,135,86,47,21,12,4,4,4,4,2,2,2,1,1],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":["#636EFA","#EF553B"]},"name":"Distribution of Delivery_Mode","x":["Vaginally","Caesarean-section (c-section)"],"y":[3904,1633],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":["#636EFA","#EF553B"]},"name":"Distribution of NICU_Stay","x":["No","Yes"],"y":[4986,548],"type":"bar","xaxis":"x5","yaxis":"y5"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}], ...

# %%
# Bivariate Analysis


# Converting Gestation Period in Months
mental_health['Gestational_Age_At_Birth'] = np.round(mental_health['Gestational_Age_At_Birth']/4.33, 2)

# %%
# Create a function to determine whether Baby Weight is Healthy or Unhealthy
def healthy_weight(row):
  if pd.isnull(row['Birth_Weight']):
    return 'Data Missing'
  elif row['Birth_Weight']>2550 and row['Birth_Weight']<4000:
    return 'Healthy'
  else:
    return 'Unhealthy'

# Create a function to determine whether Baby Length is Healthy or Unhealthy
def healthy_height(row):
  if pd.isnull(row['Birth_Length']):
    return 'Data Missing'
  elif row['Birth_Length']>39 and row['Birth_Length']<61:
    return 'Healthy'
  else:
    return 'Unhealthy'

# %%
mental_health['Weight'] = mental_health.apply(healthy_weight, axis=1)
mental_health['Height'] = mental_health.apply(healthy_height, axis=1)

# %%
mental_health
# Out:
#        Maternal_Age     Household_Income    Maternal_Education  \
# 0              38.3            $200,000+        Masters degree
# 1              34.6            $200,000+  Undergraduate degree
# 3              28.8   $100,000 -$124,999        Masters degree
# 4              36.5      $40,000-$69,999  Undergraduate degree
# 5              38.3  $150,000 - $174,999  Undergraduate degree
# ...             ...                  ...                   ...
# 10766          32.7      $70,000-$99,999   High school diploma
# 10767          38.3   $100,000 -$124,999  Undergraduate degree
# 10769          27.7     $20,000- $39,999  College/trade school
# 10770          23.0     $20,000- $39,999  College/trade school
# 10771          34.6      $70,000-$99,999        Masters degree
#
#        Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                       9.0            13.0
# 1                                       4.0            17.0
# 3                                       9.0            20.0
# 4                                      14.0            20.0
# 5                                       3.0             8.0
# ...                                     ...             ...
# 10766                                  15.0            27.0
# 10767                                  10.0            18.0
# 10769                                   4.0            15.0
# 10770                                  12.0            19.0
# 10771                                  18.0            30.0
#
#        Gestational_Age_At_Birth Delivery_Date(converted to month and year)  \
# 0                          9.17                                    Dec2020
# 1                           NaN                                        NaN
# 3                          8.91                                    Dec2020
# 4                          9.21                                    Oct2020
# 5                          8.91                                    Jun2020
# ...                         ...                                        ...
# 10766                       NaN                                        NaN
# 10767                       NaN                                        NaN
# 10769                       NaN                                        NaN
# 10770                       NaN                                        NaN
# 10771                      8.84                                    Mar2021
#
#        Birth_Length  Birth_Weight                  Delivery_Mode NICU_Stay  \
# 0             49.20        3431.0                      Vaginally        No
# 1               NaN           NaN                            NaN       NaN
# 3             41.00        2534.0                      Vaginally        No
# 4             53.34        3714.0  Caesarean-section (c-section)        No
# 5               NaN           NaN                            NaN       NaN
# ...             ...           ...                            ...       ...
# 10766           NaN           NaN                            NaN       NaN
# 10767           NaN           NaN                            NaN       NaN
# 10769           NaN           NaN                            NaN       NaN
# 10770           NaN           NaN                            NaN       NaN
# 10771           NaN        4196.0                            NaN       NaN
#
#        Threaten_Life  Threaten_Baby_Danger  Threaten_Baby_Harm        Weight  \
# 0                2.0                   3.0                27.0       Healthy
# 1                2.0                  33.0                92.0  Data Missing
# 3               53.0                  67.0                54.0     Unhealthy
# 4               23.0                  32.0                71.0       Healthy
# 5               29.0                  36.0                33.0  Data Missing
# ...              ...                   ...                 ...           ...
# 10766           54.0                  64.0                75.0  Data Missing
# 10767           54.0                  62.0                74.0  Data Missing
# 10769           21.0                  93.0                76.0  Data Missing
# 10770           65.0                  94.0                94.0  Data Missing
# 10771           84.0                  73.0                94.0     Unhealthy
#
#              Height
# 0           Healthy
# 1      Data Missing
# 3           Healthy
# 4           Healthy
# 5      Data Missing
# ...             ...
# 10766  Data Missing
# 10767  Data Missing
# 10769  Data Missing
# 10770  Data Missing
# 10771  Data Missing
#
# [10292 rows x 16 columns]

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs.flatten()

sns.lineplot(x='Maternal_Age', y ='Edinburgh_Postnatal_Depression_Scale',data=mental_health,ax=axs[0],color ='red', label='EPDS')
sns.lineplot(data=mental_health, y ='PROMIS_Anxiety', x='Maternal_Age',color ='blue', label='Anxiety',ax=axs[0])

sns.lineplot(data=mental_health, y ='Gestational_Age_At_Birth', x='Maternal_Age',color ='green', label='Gestattion',ax=axs[1])

plt.tight_layout()
plt.show()

# %%
sns.lineplot(data=mental_health, y ='Threaten_Life', x='Maternal_Age',color ='green', label='Threaten_Life')
sns.lineplot(data=mental_health, y ='Threaten_Baby_Danger', x='Maternal_Age',color ='yellow', label='Threaten_Baby_Danger')
sns.lineplot(data=mental_health, y ='Threaten_Baby_Harm', x='Maternal_Age',color ='red', label='Threaten_Baby_Harm')
# Out:
# <Axes: xlabel='Maternal_Age', ylabel='Threaten_Life'>

# %%
new_df = mental_health[mental_health['Delivery_Mode'].notnull()]

# %%
new_df = new_df[['Delivery_Mode','Maternal_Age']]

# %%
def age_category(row):
  if row['Maternal_Age'] <23:
    return 'Under Age'
  elif row['Maternal_Age']>=23 and row['Maternal_Age']<38:
    return 'Healthy'
  else:
    return 'Old Age'

# %%
new_df['Age_Category'] = new_df.apply(age_category, axis=1)

# %%
grouped_df = new_df.groupby(['Age_Category', 'Delivery_Mode']).size().reset_index(name='counts')

# Calculate percentage within each age category
grouped_df['percentage'] = grouped_df.groupby('Age_Category')['counts'].transform(lambda x: 100 * x / x.sum())

# %%
grouped_df
# Out:
#   Age_Category                  Delivery_Mode  counts  percentage
# 0      Healthy  Caesarean-section (c-section)    1381   28.097660
# 1      Healthy                      Vaginally    3534   71.902340
# 2      Old Age  Caesarean-section (c-section)     236   41.918295
# 3      Old Age                      Vaginally     327   58.081705
# 4    Under Age  Caesarean-section (c-section)      16   27.118644
# 5    Under Age                      Vaginally      43   72.881356

# %%
cols = ['NICU_Stay','Weight','Height']

# %%
# Hypothesis Testing "Logistic Classification" is used for knowing how Maternal_Age is associated with NICU_Stay, Weight,Height columns

# %%
mental_health['NICU_Stay'] = mental_health['NICU_Stay'].fillna('Data Missing')

# %%
import statsmodels.api as sm

# %%
# WE CHOOSE A SIGNIFICANCE LEVEL OF 30%.

#SIGNIFICANCE LEVEL MEANS THERE ARE THE NON SURE PROOF THAT WE HAVE FOR OUR ANALYSIS, GENEREALLY WE CHOOSE A SIGNIFICANCE LEVEL OF 5%, 1% , THIS MEANS THAT
#WE NEED  TOLERATE 5% OF PROOF THAT WE ARE NOT SURE OF IN OTHER WORDS, WE CAN SAY THAT WE  WANT 95% PURE AND GENUINE PROOF WHERE THERE ARE NO CHANCES OF ERROR.
# HOWEVER, JUST IMAGINE A SCENE IN MEDICAL INDUSTRY , DO WE ACTUALLY NEED  95% CHANCES TO PROOF ANY THING.


#LETS SEE WITH AN EXAMPLE , IF WE WANT TO KNOW IF A DISEASE IS KILLING PEOPLE , WILL WE ONLY CONCLUDE THIS ONLY IF 9/10 ARE KILLED , NO RIGHT.
# WE WILL SURELY DECLARE THAT THIS DISEASE IS KILLING PEOPLE IF IT EVEN KILL 6/10.

#FOR THIS REASON WE TOOK THE SIGNIFICANCE LEVEL AS 30.

# %%
alpha = 0.3

for i in cols:
    # Selecting clean data
    df = mental_health[(mental_health['Maternal_Age'].notnull()) & (mental_health[i] != 'Data Missing')].copy()

    # Binary Conversion
    if i == 'NICU_Stay':
        df['binary'] = df[i].apply(lambda x: 1 if x == 'Yes' else 0)
    else:
        df['binary'] = df[i].apply(lambda x: 1 if x == 'Unhealthy' else 0)

    # Model
    X = df['Maternal_Age']
    y = df['binary']

    x = sm.add_constant(X)

    logit_model = sm.Logit(y, x)
    result = logit_model.fit(disp=0)

    p_value = result.pvalues['Maternal_Age']

    if p_value < alpha:
        print(f"There is a statistically significant relationship between Maternal_Age and likelihood of {i}. (p-value: {p_value:.4f})")
    else:
        print(f"There is no statistically significant relationship between Maternal_Age and likelihood of {i}. (p-value: {p_value:.4f})")
# Out:
# There is a statistically significant relationship between Maternal_Age and likelihood of NICU_Stay. (p-value: 0.0184)
# There is a statistically significant relationship between Maternal_Age and likelihood of Weight. (p-value: 0.0748)
# There is no statistically significant relationship between Maternal_Age and likelihood of Height. (p-value: 0.6621)

# %% [markdown]
# ###CONCLUSIONS.
#
# - If a lady is in the age group 25-38 while conceiving she will not be under any anxiety attacks , moreover she will also not suffer from any after-pregnancy depression and can take care of herself and her new born more effectively.
#
# - If a female is conceiving beyond the age of 42, this is very risky for the baby as there are very high chances of pre-mature birth of the baby and the pre-mature birth may be in less than 7.5 months of gestation periods.
#
# - Female of the age group 25-42 are less worried about the impact of covid-19 on them and their new born health, damang, they are less worried as compared to females who conceived in less than 25 and females conceiving in after the age 45. its also evident that female after the age of 43 are more worried about the impact of covid-19 on lady and baby , this may be reason for high anxiety and after-pregnency depression in this age group
#
# - After the age of 38, there is a notable 13.9% [28-41.9%] increase in the likelihood of women requiring a c-section rather than opting for a natural delivery. this statistic underscores the physiological changes associated with maternal age and their implications for childbirth.
#
# - On testing the relationship between maternal age and [ will the new born need intensive medical supervision after birth , healthy or unhealthy weight, healthy or unhealthy height] ,by hypothesis testing , it was found that there is a significant association between the age of pregnant women and the likelihood of NICU_Stay and babe having unhealthy weight, however there is no evidence for significant association between age and height of new born.
#
# - High anxiety , depression , premature birth can be reason for admission of babe to NICU after delivery.

# %%
# Household Income

# %%
categories = mental_health['Household_Income'].unique()
categories
# Out:
# array(['$200,000+', '$100,000 -$124,999', '$40,000-$69,999',
#        '$150,000 - $174,999', nan, '$70,000-$99,999',
#        '$175,000- $199,999', '$125,000- $149,999', '$20,000- $39,999',
#        'Less than $20, 000'], dtype=object)

# %%
import plotly.express as px

#get unique categories of income
categories = mental_health['Household_Income'].unique()

for i  in categories:
  df= mental_health[mental_health['Household_Income']==i]
  fig= px.histogram(mental_health, x='PROMIS_Anxiety', color='Household_Income',
                   title='Distribution of Anxiety by household income',
                    hover_data= mental_health.columns)


fig.update_layout(
    xaxis_title="PROMIS_Anxiety",
    yaxis_title="Count",
    legend_title="Household Income",
    barmode= 'overlay'   #overlay histogram for better comparison.
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a07ca0b0-9e6a-4d32-bea1-2c9bbb7a5325" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a07ca0b0-9e6a-4d32-bea1-2c9bbb7a5325")) {                    Plotly.newPlot(                        "a07ca0b0-9e6a-4d32-bea1-2c9bbb7a5325",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Household_Income=$200,000+\u003cbr\u003ePROMIS_Anxiety=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"$200,000+","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"$200,000+","offsetgroup":"$200,000+","orientation":"v","showlegend":true,"x":[13.0,17.0,15.0,14.0,8.0,28.0,13.0,17.0,23.0,20.0,29.0,16.0,26.0,20.0,12.0,24.0,26.0,9.0,12.0,11.0,21.0,27.0,15.0,26.0,25.0,22.0,8.0,25.0,24.0,17.0,8.0,9.0,22.0,18.0,27.0,7.0,10.0,13.0,11.0,15.0,24.0,11.0,21.0,17.0,11.0,14.0,22.0,10.0,17.0,12.0,17.0,19.0,null,15.0,17.0,19.0,13.0,20.0,11.0,25.0,11.0,20.0,19.0,25.0,25.0,17.0,20.0,15.0,12.0,15.0,8.0,19.0,11.0,24.0,26.0,27.0,20.0,14.0,10.0,18.0,18.0,19.0,null,9.0,16.0,30.0,19.0,13.0,20.0,32.0,20.0,14.0,17.0,14.0,17.0,null,7.0,18.0,12.0,11.0,10.0,23.0,12.0,27.0,26.0,24.0,14.0,21.0,23.0,18.0,15.0,13.0,26.0,19.0,8.0,8.0,11.0,15.0,31.0,12.0,23.0,18.0,21.0,21.0
,12.0,14.0,null,25.0,22.0,25.0,21.0,15.0,21.0,9.0,15.0,23.0,16.0,17.0,12.0,16.0,18.0,null,19.0,16.0,14.0,11.0,20.0,24.0,15.0,20.0,15.0,27.0,17.0,20.0,10.0,19.0,20.0,20.0,27.0,8.0,13.0,27.0,22.0,null,17.0,20.0,15.0,12.0,9.0,28.0,20.0,null,16.0,19.0,27.0,24.0,19.0,7.0,14.0,22.0,8.0,19.0,12.0,7.0,12.0,20.0,24.0,19.0,15.0,10.0,9.0,25.0,25.0,28.0,16.0,20.0,17.0,10.0,28.0,19.0,28.0,11.0,21.0,14.0,13.0,12.0,null,11.0,12.0,25.0,8.0,14.0,20.0,14.0,13.0,27.0,23.0,24.0,9.0,18.0,13.0,8.0,8.0,14.0,25.0,21.0,18.0,27.0,23.0,12.0,13.0,8.0,null,12.0,19.0,25.0,18.0,8.0,16.0,27.0,null,9.0,14.0,29.0,13.0,7. ...

# %%
import plotly.express as px

#get unique categories of income
categories = mental_health['Household_Income'].unique()

for i  in categories:
  df= mental_health[mental_health['Household_Income']==i]
  fig= px.histogram(mental_health, x='Edinburgh_Postnatal_Depression_Scale', color='Household_Income',
                   title='Distribution of EPDS by household income',
                    hover_data= mental_health.columns)


fig.update_layout(
    xaxis_title="Edinburgh_Postnatal_Depression_Scale",
    yaxis_title="Count",
    legend_title="Household Income",
    barmode= 'overlay'   #overlay histogram for better comparison.
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d4d7159c-2970-4d0c-9adf-e6f81c58a3ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4d7159c-2970-4d0c-9adf-e6f81c58a3ff")) {                    Plotly.newPlot(                        "d4d7159c-2970-4d0c-9adf-e6f81c58a3ff",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Household_Income=$200,000+\u003cbr\u003eEdinburgh_Postnatal_Depression_Scale=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"$200,000+","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"$200,000+","offsetgroup":"$200,000+","orientation":"v","showlegend":true,"x":[9.0,4.0,8.0,3.0,0.0,15.0,6.0,9.0,7.0,8.0,15.0,10.0,13.0,8.0,5.0,10.0,13.0,6.0,5.0,1.0,6.0,16.0,6.0,9.0,12.0,17.0,10.0,10.0,19.0,5.0,1.0,4.0,17.0,6.0,17.0,0.0,3.0,10.0,8.0,6.0,13.0,3.0,13.0,14.0,3.0,8.0,11.0,9.0,6.0,6.0,4.0,8.0,null,8.0,4.0,11.0,7.0,8.0,2.0,12.0,2.0,12.0,12.0,16.0,9.0,10.0,13.0,7.0,9.0,4.0,5.0,9.0,4.0,10.0,16.0,16.0,10.0,3.0,5.0,8.0,6.0,4.0,null,2.0,3.0,11.0,10.0,9.0,11.0,14.0,8.0,8.0,12.0,4.0,10.0,null,4.0,9.0,3.0,2.0,0.0,13.0,7.0,13.0,15.0,13.0,3.0,14.0,4.0,11.0,13.0,3.0,19.0,12.0,1.0,2.0,2.0,7.0,18.0,2.0,10.0,8.0,12.0,13.0,5.0,16.0,5.0,12.0,14.0,5.0,5.0,null,1.0,7.0,12.0,1.0,6.0,6.0,13.0,15.0,0.0,7.0,10.0,19.0,10.0,5.0,15.0,13.0,22.0,7.0,13.0,10.0,5
.0,11.0,5.0,5.0,7.0,7.0,16.0,2.0,6.0,19.0,13.0,null,3.0,10.0,6.0,2.0,2.0,18.0,9.0,null,4.0,7.0,16.0,15.0,13.0,4.0,6.0,19.0,6.0,7.0,1.0,2.0,3.0,8.0,11.0,9.0,8.0,5.0,6.0,12.0,14.0,17.0,6.0,8.0,9.0,5.0,18.0,14.0,11.0,0.0,9.0,7.0,7.0,4.0,null,7.0,1.0,6.0,1.0,4.0,11.0,6.0,5.0,10.0,6.0,16.0,0.0,12.0,10.0,1.0,1.0,10.0,13.0,6.0,8.0,22.0,21.0,6.0,8.0,3.0,null,6.0,10.0,12.0,8.0,3.0,11.0,16.0,null,3.0,11.0,18.0,7.0,0.0,12.0,9.0,6.0,9.0,4.0,3.0,8.0,3.0,11.0,6.0,4.0,15.0,9.0,5.0,16.0,2.0,6.0,9.0,null,10.0,14.0,13.0,11.0,11.0,6.0,18.0,19.0,2.0,5.0,14.0,2.0,12.0,10.0,3.0,11.0,12.0,7.0,9.0,null,14.0,8.0,10.0,14.0,null,5.0,10.0,6.0,null,10.0,16.0,15.0,1.0,24.0,13.0,12.0,14.0,18.0,0.0, ...

# %%
df = mental_health[mental_health['Threaten_Life'].notnull()]
df.groupby('Household_Income')['Threaten_Life'].mean().reset_index().sort_values('Threaten_Life', ascending=False)
# Out:
#       Household_Income  Threaten_Life
# 8   Less than $20, 000      50.771028
# 4     $20,000- $39,999      47.727106
# 6      $40,000-$69,999      45.215491
# 7      $70,000-$99,999      42.388205
# 0   $100,000 -$124,999      41.783813
# 2  $150,000 - $174,999      41.392463
# 1   $125,000- $149,999      40.482463
# 3   $175,000- $199,999      40.062300
# 5            $200,000+      39.456635

# %%
df = mental_health[mental_health['Threaten_Baby_Danger'].notnull()]
df.groupby('Household_Income')['Threaten_Baby_Danger'].mean().reset_index().sort_values('Threaten_Baby_Danger', ascending=False)
# Out:
#       Household_Income  Threaten_Baby_Danger
# 8   Less than $20, 000             60.276995
# 4     $20,000- $39,999             58.310786
# 6      $40,000-$69,999             53.740031
# 7      $70,000-$99,999             52.033933
# 0   $100,000 -$124,999             50.288200
# 1   $125,000- $149,999             48.904762
# 2  $150,000 - $174,999             48.456382
# 3   $175,000- $199,999             46.923200
# 5            $200,000+             46.885057

# %%
df = mental_health[mental_health['Threaten_Baby_Harm'].notnull()]
df.groupby('Household_Income')['Threaten_Baby_Harm'].mean().reset_index().sort_values('Threaten_Baby_Harm', ascending=False)
# Out:
#       Household_Income  Threaten_Baby_Harm
# 8   Less than $20, 000           66.985915
# 4     $20,000- $39,999           66.718464
# 7      $70,000-$99,999           63.633470
# 6      $40,000-$69,999           63.476263
# 0   $100,000 -$124,999           62.386327
# 1   $125,000- $149,999           62.027301
# 3   $175,000- $199,999           60.517572
# 5            $200,000+           60.134937
# 2  $150,000 - $174,999           59.983501

# %% [markdown]
# ### CONCLUSIONS
#
# - It is evident from the observations that individuals living below the poverty line ($70,000) are significantly more susceptible to anxiety and EPDS (Edinburgh Postnatal Depression Scale) scores. Within this income bracket, nearly 70% of the population has been diagnosed with anxiety and depression, exacerbated by the conditions brought on by the COVID-19 pandemic.
#
# - There is a positive correlation between increased income and reduced probability of anxiety and depression. High-income individuals have approximately a 33% chance of being diagnosed with anxiety and depression due to COVID-19, indicating a substantial mental health benefit associated with higher income levels.
#
#
# - The COVID-19 pandemic has had a profoundly adverse impact on low-income families, particularly those below the survival line. The shortage of income has heightened their worries about the well-being of their children and women. Families below the survival line exhibit a very high threatening score for women, with an average score of 51/100. In contrast, as income levels rise, concerns diminish, likely due to better access to healthcare facilities for higher-income families.
#
# - Unlike the varying threatening scores for women across income levels, the concern for the impact of COVID-19 on newborns is universal. Regardless of income, all categories show significant worry about potential harm and damage to newborns, which may contribute to high anxiety levels in pregnant women during the pandemic.

# %%
# Maternal_Education

# %%
categories = mental_health['Maternal_Education'].unique()
categories
# Out:
# array(['Masters degree', 'Undergraduate degree', 'High school diploma',
#        nan, 'College/trade school', 'Less than high school diploma',
#        'Doctoral Degree'], dtype=object)

# %%
import plotly.express as px

#get unique categories of Maternal education
categories = mental_health['Maternal_Education'].unique()

for i  in categories:
  df= mental_health[mental_health['Maternal_Education']==i]
  fig= px.histogram(mental_health, x='PROMIS_Anxiety', color='Maternal_Education',
                   title='Distribution of Anxiety by Maternal Education',
                    hover_data= mental_health.columns)


fig.update_layout(
    xaxis_title="Maternal_Education",
    yaxis_title="Count",
    legend_title="Maternal Education",
    barmode= 'overlay'   #overlay histogram for better comparison.
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="47b6953f-402f-49bb-bd15-21d773aa2ef2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47b6953f-402f-49bb-bd15-21d773aa2ef2")) {                    Plotly.newPlot(                        "47b6953f-402f-49bb-bd15-21d773aa2ef2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Maternal_Education=Masters degree\u003cbr\u003ePROMIS_Anxiety=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Masters degree","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Masters degree","offsetgroup":"Masters degree","orientation":"v","showlegend":true,"x":[13.0,20.0,17.0,31.0,18.0,16.0,18.0,null,16.0,16.0,17.0,25.0,19.0,8.0,14.0,30.0,17.0,17.0,15.0,21.0,24.0,19.0,11.0,27.0,27.0,26.0,11.0,13.0,12.0,21.0,30.0,19.0,22.0,14.0,22.0,20.0,14.0,27.0,28.0,13.0,9.0,29.0,23.0,26.0,15.0,15.0,20.0,25.0,8.0,17.0,22.0,12.0,24.0,25.0,25.0,21.0,21.0,18.0,21.0,12.0,8.0,12.0,26.0,21.0,21.0,9.0,17.0,17.0,19.0,14.0,25.0,17.0,14.0,9.0,19.0,20.0,13.0,23.0,17.0,18.0,17.0,10.0,13.0,null,16.0,7.0,20.0,25.0,18.0,25.0,15.0,11.0,12.0,13.0,21.0,16.0,12.0,27.0,14.0,17.0,20.0,15.0,12.0,19.0,19.0,15.0,15.0,22.0,23.0,20.0,14.0,12.0,20.0,17.0,22.0,22.0,10.0,23.0,18.0,24.0,19.0,21.0,28.0,12.0,20.0,24.0,11.0,32.0,7.0,26.0,8.0,19.0,8.0,null,18.0,15.0,18.0,21.0,18.0,11.0,27.0,15.0,null,10
,16.0,5.0,5.0,null,3.0,16.0,10.0,14.0,4.0,18.0,6.0,9.0,3.0,5.0,12.0,19.0,17.0,8.0,10.0,1.0,8.0,16.0,17.0,5.0,14.0,8.0,10.0,4.0,14.0,8.0,0.0,2.0,10.0,0.0,7.0,0.0,9.0,10.0,10.0,11.0,9.0,12.0,7.0,6.0,9.0,5.0,null,15.0,2.0,17.0,13.0,8.0,10.0,3.0,8.0,2.0,8.0,2.0,0.0,18.0,12.0,10.0,17.0,9.0,null,23.0,11.0,12.0,13.0,10.0,null,2.0,17.0,6.0,14.0,14.0,13.0,10.0,17.0,0.0,13.0,3.0,8.0,14.0,22.0,13.0,17.0,12.0,12.0,10.0,null,18.0,2.0,15.0,3.0,7.0,null,6.0,5.0,4.0,9.0,14.0,13.0,9.0,16 ...

# %%
df = mental_health[mental_health['Threaten_Life'].notnull()]
df.groupby('Maternal_Education')['Threaten_Life'].mean().reset_index().sort_values('Threaten_Life', ascending=False)
# Out:
#               Maternal_Education  Threaten_Life
# 2            High school diploma      44.516169
# 0           College/trade school      44.093339
# 3  Less than high school diploma      43.767241
# 5           Undergraduate degree      42.419263
# 4                 Masters degree      39.868071
# 1                Doctoral Degree      39.566088

# %%
df = mental_health[mental_health['Threaten_Baby_Danger'].notnull()]
df.groupby('Maternal_Education')['Threaten_Baby_Danger'].mean().reset_index().sort_values('Threaten_Baby_Danger', ascending=False)
# Out:
#               Maternal_Education  Threaten_Baby_Danger
# 2            High school diploma             55.513076
# 3  Less than high school diploma             55.191304
# 0           College/trade school             53.872153
# 5           Undergraduate degree             50.271688
# 4                 Masters degree             47.371951
# 1                Doctoral Degree             46.349800

# %%
df = mental_health[mental_health['Threaten_Baby_Harm'].notnull()]
df.groupby('Maternal_Education')['Threaten_Baby_Harm'].mean().reset_index().sort_values('Threaten_Baby_Harm', ascending=False)
# Out:
#               Maternal_Education  Threaten_Baby_Harm
# 3  Less than high school diploma           65.008621
# 2            High school diploma           64.537129
# 0           College/trade school           64.108540
# 5           Undergraduate degree           62.577512
# 4                 Masters degree           60.399225
# 1                Doctoral Degree           58.728972

# %% [markdown]
# ###Conclusions
# - **Higher Anxiety and Depression in Lower Education Levels:** Individuals with a high school diploma or less exhibit significantly higher levels of anxiety and postnatal depression. This group also has the highest concerns about life-threatening situations and baby safety.
#
# - **Reduced Anxiety and Depression with Higher Education:** There is a notable decrease in anxiety and postnatal depression among individuals with higher education levels (master's and doctoral degrees). These individuals also show lower concerns about life-threatening situations and baby safety.
#
# - **Life-Threatening Concerns Correlated with Education:** Those with high school diplomas have the highest average life-threatening concerns (44.52), while those with doctoral degrees have the lowest (39.57).
#
# - **Universal Concern for Baby Safety:** While concerns about baby danger and harm are highest among those with less education, all groups show significant worries, indicating a universal concern for baby safety during the COVID-19 pandemic.

# %%
# Edinburgh_Postnatal_Depression_Scale

# %%
fig,axs= plt.subplots(1,3, figsize=(10,5))
axs= axs.flatten()


sns.lineplot(x='Edinburgh_Postnatal_Depression_Scale', y='Gestational_Age_At_Birth', data=mental_health, color='red', ax=axs[0])
sns.lineplot(x='Edinburgh_Postnatal_Depression_Scale', y='PROMIS_Anxiety', data=mental_health, color='blue', ax=axs[1])
sns.lineplot(x='Edinburgh_Postnatal_Depression_Scale', y='Birth_Weight', data=mental_health, color='green', ax=axs[2])

plt.tight_layout()
plt.show()

# %%
# Weight and delivery mode

# %%
df1= mental_health[mental_health['Weight']!='Data Missing']

# %%
df1= df1[df1['Delivery_Mode'].notnull()]

# %%
grouped_df1 = df1.groupby('Weight')['Delivery_Mode'].value_counts().reset_index(name='counts')
grouped_df1['percentage'] = grouped_df1.groupby('Weight')['counts'].transform(lambda x: 100 * x / x.sum())
grouped_df1
# Out:
#       Weight                  Delivery_Mode  counts  percentage
# 0    Healthy                      Vaginally    3318   72.067767
# 1    Healthy  Caesarean-section (c-section)    1286   27.932233
# 2  Unhealthy                      Vaginally     584   62.795699
# 3  Unhealthy  Caesarean-section (c-section)     346   37.204301

# %%
# weight and NICU stay
df1= mental_health[mental_health['Weight']!='Data Missing']

# %%
df1= df1[df1['NICU_Stay']!='Data Missing']

# %%
grouped_df1 = df1.groupby('Weight')['NICU_Stay'].value_counts().reset_index(name='counts')
grouped_df1['percentage'] = grouped_df1.groupby('Weight')['counts'].transform(lambda x: 100 * x / x.sum())
grouped_df1
# Out:
#       Weight NICU_Stay  counts  percentage
# 0    Healthy        No    4256    92.48153
# 1    Healthy       Yes     346     7.51847
# 2  Unhealthy        No     728    78.27957
# 3  Unhealthy       Yes     202    21.72043

# %%
#height and delivery mode
df1= mental_health[mental_health['Height']!='Data Missing']
df1= df1[df1['Delivery_Mode'].notnull()]
grouped_df1 = df1.groupby('Height')['Delivery_Mode'].value_counts().reset_index(name='counts')
grouped_df1['percentage'] = grouped_df1.groupby('Height')['counts'].transform(lambda x: 100 * x / x.sum())
grouped_df1
# Out:
#       Height                  Delivery_Mode  counts  percentage
# 0    Healthy                      Vaginally    3763   70.826275
# 1    Healthy  Caesarean-section (c-section)    1550   29.173725
# 2  Unhealthy                      Vaginally     104   62.275449
# 3  Unhealthy  Caesarean-section (c-section)      63   37.724551

# %%
#height and NICU STAY
df1= mental_health[mental_health['Height']!='Data Missing']
df1= df1[df1['NICU_Stay'].notnull()]
grouped_df1 = df1.groupby('Height')['NICU_Stay'].value_counts().reset_index(name='counts')
grouped_df1['percentage'] = grouped_df1.groupby('Height')['counts'].transform(lambda x: 100 * x / x.sum())
grouped_df1
# Out:
#       Height NICU_Stay  counts  percentage
# 0    Healthy        No    4808   90.495012
# 1    Healthy       Yes     505    9.504988
# 2  Unhealthy        No     130   77.844311
# 3  Unhealthy       Yes      37   22.155689

# %% [markdown]
# ### CONCLUSIONS
#
# - Observational data indicates a significant correlation between high EPDS scores and the likelihood of pre-mature births. However, it's important to note that these pre-mature births generally occur after 8.5 months of gestation, which falls within the medically accepted range and thus, poses minimal health risks to the newborn.
#
# - Women experiencing high levels of EPDS or anxiety are likely to experience the other condition at similar intensity levels. This linear association suggests that an increase in one condition directly correlates with an increase in the other, highlighting the intertwined nature of these mental health challenges.
#
# - There is a 37% probability that women with babies of unhealthy birth weight will undergo a C-section, which is 10% higher than the likelihood for those with babies of healthy birth weight. This pattern is similarly observed with birth height, indicating a strong link between unhealthy birth metrics and the necessity for C-sections.
#
# - A particularly alarming statistic is that babies with unhealthy birth weight have a 22% chance of requiring a NICU stay, which is 15% higher than for babies with healthy birth weight. This same trend is evident with birth height, underscoring the critical importance of healthy birth metrics in reducing the need for intensive neonatal care.

# %%
#MUTIVARIATE ANALYSIS.

# %%
#VULNERABLE GROUPS-  These are the groups that are mostly effected when any pendamic occurs.

#survival income = $70,000

# %%
mental_health.groupby(
    ['Maternal_Age','Household_Income','Maternal_Education']
)['Edinburgh_Postnatal_Depression_Scale'].mean().reset_index().sort_values(
    'Edinburgh_Postnatal_Depression_Scale', ascending=False
).head(30)
# Out:
#       Maternal_Age     Household_Income             Maternal_Education  \
# 2644          34.3     $20,000- $39,999           College/trade school
# 51            20.5      $40,000-$69,999           College/trade school
# 2037          32.1      $40,000-$69,999            High school diploma
# 4048          42.2      $40,000-$69,999           College/trade school
# 992           28.2   Less than $20, 000           College/trade school
# 27            19.6     $20,000- $39,999            High school diploma
# 42            20.2   Less than $20, 000           College/trade school
# 3274          36.7      $40,000-$69,999  Less than high school diploma
# 627           26.5     $20,000- $39,999           Undergraduate degree
# 1714          31.0     $20,000- $39,999            High school diploma
# 395           25.0      $70,000-$99,999           College/trade school
# 2169          32.6  $150,000 - $174,999           College/trade school
# 1038          28.4      $40,000-$69,999            High school diploma
# 216           23.4      $40,000-$69,999            High school diploma
# 2001          32.0     $20,000- $39,999                 Masters degree
# 3803          39.5     $20,000- $39,999           College/trade school
# 1685          30.9     $20,000- $39,999           Undergraduate degree
# 4135          45.0      $70,000-$99,999           College/trade school
# 968           28.1   Less than $20, 000           College/trade school
# 942           28.0      $40,000-$69,999  Less than high school diploma
# 2             17.9   Less than $20, 000  Less than high school diploma
# 1273          29.3      $70,000-$99,999            High school diploma
# 296           24.2   Less than $20, 000           Undergraduate degree
# 689           26.8      $40,000-$69,999  Less than high school diploma
# 186           23.0      $70,000-$99,999           College/trade school
# 4119          44.0      $40,000-$69,999           Undergraduate degree
# 3860          40.0  $150,000 - $174,999                Doctoral Degree
# 3904          40.3      $40,000-$69,999                 Masters degree
# 10            18.6      $40,000-$69,999  Less than high school diploma
# 3455          37.5      $70,000-$99,999            High school diploma
#
#       Edinburgh_Postnatal_Depression_Scale
# 2644                                  29.0
# 51                                    29.0
# 2037                                  28.0
# 4048                                  28.0
# 992                                   27.0
# 27                                    27.0
# 42                                    27.0
# 3274                                  26.0
# 627                                   26.0
# 1714                                  26.0
# 395                                   26.0
# 2169                                  26.0
# 1038                                  26.0
# 216                                   26.0
# 2001                                  25.0
# 3803                                  25.0
# 1685                                  25.0
# 4135                                  25.0
# 968                                   25.0
# 942                                   25.0
# 2                                     25.0
# 1273                                  24.5
# 296                                   24.0
# 689                                   24.0
# 186                                   24.0
# 4119                                  24.0
# 3860                                  24.0
# 3904                                  24.0
# 10                                    24.0
# 3455                                  24.0

# %%
#lets see  the probability of   women with low EPDS  having high  Anxiety

a= len(mental_health[mental_health['Edinburgh_Postnatal_Depression_Scale']<12])
b= len(mental_health[(mental_health['Edinburgh_Postnatal_Depression_Scale']<12)&(mental_health['PROMIS_Anxiety']>20)])

print(f"Probability of women having low EPDS and high Anxiety is {(b/a)*100}")


#lets see  the probability of   women with high EPDS  having high  Anxiety

a= len(mental_health[mental_health['Edinburgh_Postnatal_Depression_Scale']>12])
b= len(mental_health[(mental_health['Edinburgh_Postnatal_Depression_Scale']>12)&(mental_health['PROMIS_Anxiety']>20)])

print(f"Probability of women having high EPDS and high Anxiety is {(b/a)*100}")
# Out:
# Probability of women having low EPDS and high Anxiety is 14.884768670940913
# Probability of women having high EPDS and high Anxiety is 81.31833801936895

# %%
df= mental_health.copy()

# %%
df= df[(df['Threaten_Life'].notnull())&(df['Threaten_Baby_Harm'].notnull())&(df['Threaten_Baby_Danger'].notnull())]

# %%
df.groupby(
    ['Maternal_Age','Household_Income','Maternal_Education']
).agg({'Threaten_Life':'mean','Threaten_Baby_Harm':'mean','Threaten_Baby_Danger':'mean'}).reset_index().sort_values(
    by= ['Threaten_Life','Threaten_Baby_Harm','Threaten_Baby_Danger'], ascending=False
).head(40)
# Out:
#       Maternal_Age     Household_Income             Maternal_Education  \
# 53            20.6     $20,000- $39,999            High school diploma
# 524           25.9     $20,000- $39,999           College/trade school
# 761           27.2      $40,000-$69,999           College/trade school
# 876           27.8   $100,000 -$124,999                 Masters degree
# 898           27.9   $100,000 -$124,999           College/trade school
# 932           28.0      $40,000-$69,999           College/trade school
# 969           28.2  $150,000 - $174,999           College/trade school
# 1460          30.1   Less than $20, 000           College/trade school
# 1557          30.5     $20,000- $39,999            High school diploma
# 2245          32.9      $40,000-$69,999            High school diploma
# 2628          34.3      $40,000-$69,999            High school diploma
# 2837          35.1     $20,000- $39,999  Less than high school diploma
# 3487          37.8   Less than $20, 000                 Masters degree
# 4004          42.2      $40,000-$69,999           College/trade school
# 4065          43.8     $20,000- $39,999           College/trade school
# 4023          42.6   Less than $20, 000           Undergraduate degree
# 1215          29.1   Less than $20, 000  Less than high school diploma
# 1225          29.2   $175,000- $199,999                Doctoral Degree
# 4027          42.7   $125,000- $149,999           Undergraduate degree
# 2700          34.6     $20,000- $39,999            High school diploma
# 875           27.8   $100,000 -$124,999            High school diploma
# 1982          32.0     $20,000- $39,999                 Masters degree
# 3892          40.7   $125,000- $149,999                Doctoral Degree
# 3193          36.5     $20,000- $39,999           College/trade school
# 2253          33.0   $100,000 -$124,999                Doctoral Degree
# 3904          40.8   $175,000- $199,999           College/trade school
# 2788          34.9      $40,000-$69,999           College/trade school
# 2845          35.1      $70,000-$99,999                 Masters degree
# 3629          38.6  $150,000 - $174,999            High school diploma
# 316           24.4   Less than $20, 000           College/trade school
# 2             17.9   Less than $20, 000  Less than high school diploma
# 215           23.4      $40,000-$69,999            High school diploma
# 2323          33.2   $175,000- $199,999           Undergraduate degree
# 468           25.5      $70,000-$99,999           Undergraduate degree
# 480           25.6      $40,000-$69,999           Undergraduate degree
# 764           27.2      $70,000-$99,999            High school diploma
# 2100          32.4     $20,000- $39,999                 Masters degree
# 188           23.1     $20,000- $39,999           College/trade school
# 368           24.8   Less than $20, 000           College/trade school
# 3340          37.1   Less than $20, 000           College/trade school
#
#       Threaten_Life  Threaten_Baby_Harm  Threaten_Baby_Danger
# 53            100.0               100.0                 100.0
# 524           100.0               100.0                 100.0
# 761           100.0               100.0                 100.0
# 876           100.0               100.0                 100.0
# 898           100.0               100.0                 100.0
# 932           100.0               100.0                 100.0
# 969           100.0               100.0                 100.0
# 1460          100.0               100.0                 100.0
# 1557          100.0               100.0                 100.0
# 2245          100.0               100.0                 100.0
# 2628          100.0               100.0                 100.0
# 2837          100.0               100.0                 100.0
# 3487          100.0               100.0                 100.0
# 4004          100.0               100.0                 100.0
# 4065          100.0               100.0                  98.0
# 4023          100.0               100.0                  96.0
# 1215          100.0               100.0                  95.0
# 1225          100.0               100.0                  86.0
# 4027          100.0               100.0                  85.0
# 2700          100.0               100.0                  72.0
# 875           100.0                98.0                 100.0
# 1982          100.0                97.0                  93.0
# 3892          100.0                96.0                  95.0
# 3193          100.0                95.0                  99.0
# 2253          100.0                95.0                  96.0
# 3904          100.0                94.0                  89.0
# 2788          100.0                93.0                  94.0
# 2845          100.0                92.0                  96.0
# 3629          100.0                88.0                  92.0
# 316           100.0                88.0                  78.0
# 2             100.0                83.0                  68.0
# 215           100.0                79.0                 100.0
# 2323          100.0                70.0                  60.0
# 468            99.0               100.0                  98.0
# 480            99.0                96.0                  97.0
# 764            99.0                95.0                  99.0
# 2100           99.0                94.0                  97.0
# 188            99.0                94.0                  71.0
# 368            99.0                11.0                  95.0
# 3340           98.0               100.0                  99.0

# %% [markdown]
# ### CONCLUSIONS
# - The most vulnerable group to high scores on the Edinburgh Postnatal Depression Scale (EPDS) consists of women of all age groups with low household income and low education levels. However, there are notable instances where women from high-income and highly educated backgrounds are also susceptible to high EPDS scores. This vulnerability predominantly affects women aged 40 and above, suggesting that advanced maternal age can be a significant risk factor for depression during pregnancy and postpartum.
#
#
# - There is a 14% likelihood that women with low EPDS (depression) scores will experience high anxiety. Conversely, women with high EPDS scores have an 81% chance of also experiencing high anxiety, particularly exacerbated by the stress and uncertainties brought on by the COVID-19 pandemic. This strong correlation underscores the compounded mental health challenges faced by this group during such crises.
#
# - Families with low income, regardless of age and education levels, exhibit heightened concerns about the health and safety of the mother and newborn due to COVID-19. This widespread anxiety reflects the profound impact of socioeconomic status on perceived vulnerability and health security during the pandemic
#
# - Individuals with a master’s degree but low income, and those with high income but lower education levels, share similar levels of concern about the impact of COVID-19 on the mother and newborn. This finding highlights that both education and income are equally significant factors in determining the level of worry and perceived risk related to the pandemic's effects on maternal and infant health.
